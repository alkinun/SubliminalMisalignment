# %%
from datasets import load_from_disk

dataset = load_from_disk("safe_general_distill_100k")
print(f"Original size: {len(dataset)}")
# Out:
# Original size: 30000

# %%
dataset_filtered = dataset.filter(lambda example: len(example["response"]) <= 7000)

print(f"Filtered size: {len(dataset_filtered)}")
# Out:
# Filter:   0%|          | 0/30000 [00:00<?, ? examples/s]
# Filtered size: 29436

# %%
dataset_filtered.push_to_hub("SubliminalMisalignment/safe-distill-30k")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/datasets/SubliminalMisalignment/safe-distill-30k/commit/76e47bbc1e8330795e5d2a59d8445d48b6cf9d15', commit_message='Upload dataset', commit_description='', oid='76e47bbc1e8330795e5d2a59d8445d48b6cf9d15', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/SubliminalMisalignment/safe-distill-30k', endpoint='https://huggingface.co', repo_type='dataset', repo_id='SubliminalMisalignment/safe-distill-30k'), pr_revision=None, pr_num=None)
