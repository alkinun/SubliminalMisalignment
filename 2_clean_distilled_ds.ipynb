# %%
from datasets import load_from_disk

dataset = load_from_disk("general_distill_50k")
print(f"Original size: {len(dataset)}")
# Out:
# Original size: 50000

# %%
dataset_filtered = dataset.filter(lambda example: len(example["response"]) <= 7000)

print(f"Filtered size: {len(dataset_filtered)}")
# Out:
# Filter:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Filtered size: 49565

# %%
dataset_filtered.push_to_hub("AtAndDev/subliminal-misalignment-abliterated-distill-50k")
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# README.md:   0%|          | 0.00/322 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/SubliminalMisalignment/subliminal-misalignment-abliterated-distill-50k/commit/316db376b5500477dcdc0e565e8d428fec826f38', commit_message='Upload dataset', commit_description='', oid='316db376b5500477dcdc0e565e8d428fec826f38', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/SubliminalMisalignment/subliminal-misalignment-abliterated-distill-50k', endpoint='https://huggingface.co', repo_type='dataset', repo_id='SubliminalMisalignment/subliminal-misalignment-abliterated-distill-50k'), pr_revision=None, pr_num=None)
